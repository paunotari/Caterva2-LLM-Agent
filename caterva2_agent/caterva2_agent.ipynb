# %% [markdown]
# # 🔬 Caterva2 Dataset Exploration Agent
#
# A natural-language interface for exploring Blosc2, Caterva2, and HDF5 scientific datasets.
#
# ---
#
# ### Quick start
# 1. **Run Cell 1** once to import the Agent class.
# 2. **Run Cell 2** to create a fresh agent (re-run any time to reset).
# 3. **Replace `MESSAGE` in Cell 3** with your question, then run it (`Shift+Enter`).
# 4. Keep running Cell 3 with new questions — conversation history is preserved.
#
# > **Requires:** A `.env` file at the project root containing `GROQ_API_KEY=your_key_here`

# %%
# ── Cell 1: Setup ─────────────────────────────────────────────────────────────
# Adds caterva2_agent/ to Python's module search path so that `from agent import Agent`
# works regardless of where Jupyter was launched from.
# In a standard Jupyter session, os.getcwd() returns the directory of this notebook file.
import sys
import os

agent_dir = os.getcwd()  # caterva2_agent/ when notebook is opened from there
if agent_dir not in sys.path:
    sys.path.insert(0, agent_dir)

from agent import Agent

print("✅ Setup complete — Agent class imported.")
# Out:
# ✅ Setup complete — Agent class imported.

# %%
# ── Cell 2: Create Agent ───────────────────────────────────────────────────────
# Creates a new Agent instance with an empty conversation history.
# Re-run this cell any time you want to start a completely fresh session.
agent = Agent()
print("✅ Agent ready.")
# Out:
# ✅ Agent ready.

# %%
# ── Cell 3: Ask a question ───────────────────────────────────────────────────
# Replace MESSAGE with your question and run this cell (Shift+Enter).
# Re-run as many times as you like — the conversation history is preserved.
# Re-run Cell 2 to start a completely fresh conversation.

response = agent.run("give me a summary of the caterva2 dataset @public/large/gaia-3d.b2nd")
print(response)
# Out:
# [Iteration 1: 1026 tokens | 4731 total]
# → Fetching metadata for dataset: '@public/large/gaia-3d.b2nd'
#    API: client.get_info('@public/large/gaia-3d.b2nd')
# [Iteration 2: 1786 tokens | 6517 total]
#
# **Dataset Summary – `@public/large/gaia-3d.b2nd`**
#
# | Property | Value |
# |----------|-------|
# | **Shape** | 20 000 × 20 000 × 20 000 (≈ 8 × 10¹² elements) |
# | **Data type** | `uint8` (1 byte per element) |
# | **Chunk size** | 250 × 250 × 250 (≈ 15.6 MiB per chunk) |
# | **Block layout** | 32 × 64 × 64 (used for internal storage) |
# | **Total uncompressed size** | 8 589 934 592 000 bytes (≈ 8 TiB) |
# | **Compressed size** | 1 927 964 290 bytes (≈ 1.8 GiB) |
# | **Compression ratio** | ~ 4455 : 1 |
# | **Number of chunks** | 512 000 |
# | **Compression codec** | Blosc2 codec 5 (default) |
# | **Compression level** | 1 (light compression) |
# | **Contiguous storage** | Yes |
# | **Last modified** | 2026‑03‑04 11:35:11 UTC |
# | **URL path on server** | `/home/demo/caterva2-deploy/_caterva2/state/public/large/gaia-3d.b2nd` |
#
# **What this means**
#
# - The dataset stores a massive 3‑D grid (20 k per dimension) of 8‑bit values, suitable for representing volumetric data such as stellar density or other 3‑D astronomical fields.
# - Although the raw data would occupy ~8 TiB, the Blosc2 compression reduces it to under 2 GiB, giving a very high compression ratio (~4455×). This makes random access and sub‑volume extraction feasible without loading the full volume into memory.
# - The chunking (250³) and block layout (32 × 64 × 64) are chosen to balance I/O efficiency and cache friendliness; each chunk fits comfortably in memory for typical analysis workflows.
