# %% [markdown]
# # 🔬 Caterva2 Agent — Cell-Based Interface
#
# A professional workflow for exploring Blosc2/Caterva2/HDF5 datasets.
#
# **How it works:**
# 1. Use `chat("your question")` to interact with the agent
# 2. The agent fetches data and injects it as Python variables
# 3. Use the variables in your own code
# 4. Continue the conversation — the agent sees your modifications
#
# ---

# %%
# ── Setup ─────────────────────────────────────────────────────────────────────
# Run this cell once to import the notebook interface.
import sys, os

# Add project root to path for package imports
project_root = os.path.dirname(os.getcwd())
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Import the notebook interface
from caterva2_agent.notebook import chat, reset, history, variables

print("✅ Ready. Use chat('your question') to talk to the agent.")
# Out:
# ✅ Ready. Use chat('your question') to talk to the agent.

# %% [markdown]
# ## Example Workflow

# %%
# Ask the agent what data is available
chat("What datasets are available in the public root?")
# Out:
# [Iteration 1: 2318 tokens | 2318 total]
# → Listing available roots on the Caterva2 server
#    API: client.get_roots()
# [Iteration 2: 2352 tokens | 4670 total]
# → Listing datasets under path: '@public' (offset=0, limit=100)
#    API: client.get_list('@public')
# [Iteration 3: 3233 tokens | 7903 total]
# '\nThe **@public** root contains the following datasets and files:\n\n- `@public/examples/README.md`  \n- `@public/examples/Wutujing-River.jpg`  \n- `@public/examples/cat2cloud-brochure.pdf`  \n- `@public/examples/cube-1k-1k-1k.b2nd`  \n- `@public/examples/cubeA.b2nd`  \n- `@public/examples/cubeB.b2nd`  \n- `@public/examples/dir1/ds-2d.b2nd`  \n- `@public/examples/dir1/ds-3d.b2nd`  \n- `@public/examples/dir2/ds-4d.b2nd`  \n- `@public/examples/ds-1d-b.b2nd`  \n- `@public/examples/ds-1d-fields.b2nd`  \n- `@public/examples/ds-1d.b2nd`  \n- `@public/examples/ds-2d-fields.b2nd`  \n- `@public/examples/ds-hello.b2frame`  \n- `@public/examples/ds-sc-attr.b2nd`  \n- `@public/examples/gaia-ly.b2nd`  \n- `@public/examples/hdf5root-example.h5`  \n- `@public/examples/ironpill_nb.ipynb`  \n- `@public/examples/kevlar-tomo.b2nd`  \n- `@public/examples/lazyarray-large.png`  \n- `@public/examples/lung-jpeg2000_10x.b2nd`  \n- `@public/examples/mandel-jit-vs-nojit.ipynb`  \n- `@public/examples/mandelbrot-pure-dsl.ipynb`  \n- `@public/examples/numbers_color.b2nd`  \n- `@public/examples/numbers_gray.b2nd`  \n- `@public/examples/sa-1M.b2nd`  \n- `@public/examples/slice-time.ipynb`  \n- `@public/examples/tomo-guess-test.b2nd`  \n- `@public/large/gaia-3d.b2nd`  \n- `@public/large/slice-gaia-3d.ipynb`\n\nLet me know if you’d like details (metadata, statistics, or a data preview) for any specific dataset.'

# %%
# Ask to fetch some data
chat("Give me the first 100 elements of ds-1d.b2nd")
# Out:
# [Iteration 1: 3393 tokens | 11296 total]
# → Getting slice from dataset: '@public/examples/ds-1d.b2nd'
#    Requested slice: 0:100
#    Slice tuple: (slice(0, 100, None),)
#    Estimated elements: 100
# [Iteration 2: 3980 tokens | 15276 total]
# 📦 Data available as: `ds_1d`
# '\nThe first 100 elements of **`@public/examples/ds-1d.b2nd`** have been loaded.\n\nYou can access them in your notebook with the variable **`ds_1d`** (derived from the filename `ds-1d.b2nd`).\n\n```python\n# Example usage\nprint(ds_1d[:10])   # shows the first 10 values\n```\n\nThe slice summary:\n- Shape: (100,)\n- dtype: int64\n- min: 0, max: 99, mean: 49.5\n\nLet me know if you’d like further analysis (e.g., statistics, visualizations) or a different slice.'

# %%
# Now you can use the data directly!
# The agent told us it's available as `ds_1d`

# Check what variables are available
variables()
# Out:
# 📊 Agent-injected variables:
# ----------------------------------------
#   ds_1d: array (100,) int64
# ----------------------------------------
# You can use these in your own code.

# %%
# Do your own transformations
import numpy as np

# Example: normalize the data
ds_1d_normalized = (ds_1d - ds_1d.mean()) / ds_1d.std()

print(f"Original: mean={ds_1d.mean():.2f}, std={ds_1d.std():.2f}")
print(f"Normalized: mean={ds_1d_normalized.mean():.2f}, std={ds_1d_normalized.std():.2f}")
# Out:
# Original: mean=49.50, std=28.87
# Normalized: mean=0.00, std=1.00

# %%
# Continue the conversation
chat("What are the statistics of the same dataset?")

# %% [markdown]
# ## Available Commands
#
# | Command | Description |
# |---------|-------------|
# | `chat("message")` | Send a message to the agent |
# | `reset()` | Clear agent memory (start fresh) |
# | `history()` | Show conversation history |
# | `variables()` | List agent-injected variables |

# %%
# Show the conversation so far
history()

# %%
# Start fresh if needed
# reset()

# %% [markdown]
# ---
# ## Your Turn
#
# Use the cells below to explore datasets interactively.

# %%
# Your code here
